# %% [markdown]
# # Module 6: Introduction to Data Analysis Tools in Python

# %% [markdown]
# ## Assignment 6.1 Introduction to Data Analysis

# %% [markdown]
# ### 6.2. Supplementary Activity

# %% [markdown]
# Run the given code and generate a list of 100 values.

# %%
import random
random.seed(0)
salaries = [round(random.random()*1000000, -3) for _ in range(100)]

# %% [markdown]
# ### Exercise 1

# %% [markdown]
# Using the generated data, calculate the following statistics without importing anything from the statistics module in the standard library (and without using pandas/numpy).
#
# Once you have computed for each, compare your obtained output with the output when using the statistics module.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# **mean**

# %%
# Calculate the mean
mean = sum(salaries)/len(salaries)
print(mean)
# Out:
# 585690.0

# %%
# Calculate the mean using numpy
mean_np = np.mean(salaries)
print(mean_np)
# Out:
# 585690.0

# %% [markdown]
# **median**

# %%
# Calculate the mean using numpy
salaries.sort()
n = len(salaries)
if n % 2 == 0:
    median = (salaries[n//2 - 1] + salaries[n//2]) / 2
else:
    median_value = salaries[n//2]
print(median)
# Out:
# 589000.0

# %%
median_np = np.median(salaries)
print(median_np)
# Out:
# 589000.0

# %% [markdown]
# **mode**

# %%
# Calculate mode
frequency = {}
for amount in salaries:
    if amount in frequency:
        frequency[amount] += 1
    else:
        frequency[amount] = 1
    
max_count = max(frequency.values())

# Find the value(s) that occur most frequently
mode = [key for key, count in frequency.items() if count == max_count]
    
print(mode)
# Out:
# [477000.0]

# %%
# Calculate mode using stats module
from scipy import stats

mode_stat = stats.mode(salaries)
print(mode_stat)
# Out:
# ModeResult(mode=np.float64(477000.0), count=np.int64(3))

# %% [markdown]
# **Sample Variance**

# %%
# Calculate variance
mean = sum(salaries)/len(salaries)
squared_diffs = [(amount - mean) ** 2 for amount in salaries]
variance = sum(squared_diffs) / (len(salaries) - 1)
print(variance)
# Out:
# 70664054444.44444

# %%
# Calculate variance using numpy
variance_np = np.var(salaries, ddof=1)
print(variance_np)
# Out:
# 70664054444.44444

# %% [markdown]
# **Sample Standard Variation**

# %%
# Calculate Sample Standard Variation
import math

std_dev = math.sqrt(variance)
print(std_dev)
# Out:
# 265827.11382484

# %%
# Calculate Sample Standard Variation using numpy
std_dev_np = np.std(salaries, ddof=1)
print(std_dev_np)
# Out:
# 265827.11382484

# %% [markdown]
# ### Exercise 2

# %% [markdown]
# Using the previously generated data, calculate the following using the functions in the statistics module where appropriate.

# %% [markdown]
# **Range**

# %%
salaries_range = max(salaries) - min(salaries)
print(salaries_range)
# Out:
# 995000.0

# %% [markdown]
# **Coefficient of Variation**

# %%
# Coefficient of variation = (standard deviation / mean) * 100
salaries_cv = (std_dev/mean)*100
print(salaries_cv)
# Out:
# 45.38699889443903

# %% [markdown]
# **Interquartile Range**

# %%
from scipy.stats import iqr
salaries_iqr = iqr(salaries)
print(salaries_iqr)
# Out:
# 413250.0

# %% [markdown]
# **Quartile Coefficient of Dispersion**

# %%
# qcd = (q3 - q1)/(q3 + q1)
q1 = np.percentile(salaries,25)
q3 = np.percentile(salaries,75)

salaries_qcd = (q3 - q1)/(q3 + q1)
print(salaries_qcd)
# Out:
# 0.338660110633067

# %% [markdown]
# ### Exercise 3

# %% [markdown]
# Load the diabetes.csv file and perform the following task:

# %%
file_path = 'data/diabetes.csv'
df = pd.read_csv(file_path)

# %% [markdown]
# 1. Identify the column names.

# %%
df.columns.tolist()
# Out:
# ['Pregnancies',
#  'Glucose',
#  'BloodPressure',
#  'SkinThickness',
#  'Insulin',
#  'BMI',
#  'DiabetesPedigreeFunction',
#  'Age',
#  'Outcome']

# %% [markdown]
# 2. Identify the data types of the data.

# %%
df.dtypes
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %% [markdown]
# 3. Display the total number of records.

# %%
df.shape[0]
# Out:
# 768

# %% [markdown]
# 4. Display the first 20 records.

# %%
df.head(20)
# Out:
#     Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0             6      148             72             35        0  33.6
# 1             1       85             66             29        0  26.6
# 2             8      183             64              0        0  23.3
# 3             1       89             66             23       94  28.1
# 4             0      137             40             35      168  43.1
# 5             5      116             74              0        0  25.6
# 6             3       78             50             32       88  31.0
# 7            10      115              0              0        0  35.3
# 8             2      197             70             45      543  30.5
# 9             8      125             96              0        0   0.0
# 10            4      110             92              0        0  37.6
# 11           10      168             74              0        0  38.0
# ...

# %% [markdown]
# 5. Display the last 20 records.

# %%
df.tail(20)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 748            3      187             70             22      200  36.4
# 749            6      162             62              0        0  24.3
# 750            4      136             70              0        0  31.2
# 751            1      121             78             39       74  39.0
# 752            3      108             62             24        0  26.0
# 753            0      181             88             44      510  43.3
# 754            8      154             78             32        0  32.4
# 755            1      128             88             39      110  36.5
# 756            7      137             90             41        0  32.0
# 757            0      123             72              0        0  36.3
# 758            1      106             76              0        0  37.5
# 759            6      190             92              0        0  35.5
# ...

# %% [markdown]
# 6. Change the Outcome column to Diagnosis.

# %%
df.rename(columns={'Outcome': 'Diagnosis'}, inplace=True)
display(df)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Diagnosis
# 0                       0.627   50          1
# ...

# %% [markdown]
# 7. Create a new column Classification that display "Diabetes" if the value of outcome is 1, otherwise "No Diabetes".

# %%
df['Classification'] = np.where(df['Diagnosis'] == 1, 'Diabetes', 'No Diabetes')
display(df)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Diagnosis Classification
# ...

# %% [markdown]
# 8. Create a new dataframe "withDiabetes" that gathers data with diabetes.

# %%
withDiabetes_df = df[df['Diagnosis'] == 1]
display(withDiabetes_df)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 2              8      183             64              0        0  23.3
# 4              0      137             40             35      168  43.1
# 6              3       78             50             32       88  31.0
# 8              2      197             70             45      543  30.5
# ..           ...      ...            ...            ...      ...   ...
# 755            1      128             88             39      110  36.5
# 757            0      123             72              0        0  36.3
# 759            6      190             92              0        0  35.5
# 761            9      170             74             31        0  44.0
# 766            1      126             60              0        0  30.1
#
#      DiabetesPedigreeFunction  Age  Diagnosis Classification
# ...

# %% [markdown]
# 9. Create a new dataframe "noDiabetes" that gathers data with no diabetes.

# %%
noDiabetes_df = df[df['Diagnosis'] == 0]
display(noDiabetes_df)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 1              1       85             66             29        0  26.6
# 3              1       89             66             23       94  28.1
# 5              5      116             74              0        0  25.6
# 7             10      115              0              0        0  35.3
# 10             4      110             92              0        0  37.6
# ..           ...      ...            ...            ...      ...   ...
# 762            9       89             62              0        0  22.5
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Diagnosis Classification
# ...

# %% [markdown]
# 10. Create a new dataframe "Pedia" that gathers data with age 0 to 19.

# %%
pedia_df = df[df['Age'] <= 19]
display(pedia_df)
# Out:
# Empty DataFrame
# Columns: [Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age, Diagnosis, Classification]
# Index: []

# %% [markdown]
# 11. Create a new dataframe "Adult" that  gathers data with age greater than 19.

# %%
adult_df = df[df['Age'] > 19]
display(adult_df)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Diagnosis Classification
# ...

# %% [markdown]
# 12. Use numpy to get the average age and glucose value.

# %%
ave_age = np.mean(df['Age'])
ave_glucose = np.mean(df['Glucose'])

print(ave_age)
print(ave_glucose)
# Out:
# 33.240885416666664
# 120.89453125

# %% [markdown]
# 13. Use numpy to get the middle values of glucose and age.

# %%
median_age = np.median(df['Age'])
median_glucose = np.median(df['Glucose'])

print(median_age)
print(median_glucose)
# Out:
# 29.0
# 117.0

# %% [markdown]
# 14. Use numpy to get the standard deviation of the skinthickness.

# %%
std_skinthickness = np.std(df['SkinThickness'])
print(std_skinthickness)
# Out:
# 15.941828626496939

# %% [markdown]
# ### Chosen Dataset

# %% [markdown]
# On your chosen dataset, perform the following:

# %% [markdown]
# 1. Load the data, check the information on the dataset.

# %% [markdown]
# 2. Display the first 10 and last 10 rows.

# %% [markdown]
# 3. Choose a column with a numerical value, change its type to int64 and store in a new column.

# %% [markdown]
# 4. Choose a column with a non-numerical value (that can act as a category), create a new column that contains the mapped values of the categorical column from 0 to n-1. (E.g. Iris-Setosa is 0, Iris-versicolor is 1, Iris-virginica is 2).

# %% [markdown]
# 5. Create a column that would have the value YES or NO depending on a conditional statement you will create based on values in the dataset. (E.g. "Age > 18 == Adult | YES OR NO")

# %% [markdown]
# ### 6.3 Conclusion
